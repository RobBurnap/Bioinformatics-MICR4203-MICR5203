# %% [markdown]
# <a href="https://colab.research.google.com/github/RobBurnap/Bioinformatics-MICR4203-MICR5203/blob/main/notebooks/02_Sequence_Alignment/01_BLASTp_and_Species_Tree_Diversity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BIOINFO4/5203 —
# species diversity BLASTp:  Need two files in your

# %% [markdown]
# ##A. Mount Google Drive, Import Coding Libraries Necessary for Running Subsequent Code

# %%
# Install FIRST, then import
# %pip install -q biopython       # Install the Biopython package quietly (-q suppresses most output) so we can work with biological sequence files

from google.colab import drive  # Import the module that lets Colab interact with Google Drive
drive.mount('/content/drive')   # Mount your Google Drive so it appears in Colab's file system under /content/drive

import os, pandas as pd          # Import 'os' for file/directory operations, and pandas for working with data tables
from Bio import SeqIO            # Import SeqIO from Biopython for reading/writing biological sequence files (FASTA, GenBank, etc.)
import matplotlib.pyplot as plt  # Import Matplotlib's plotting library to create figures and graphs

print("✅ Dependencies installed & Drive mounted.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Dependencies installed & Drive mounted.

# %% [markdown]
# ## B. Course folders: Define the course folders for places to load data to be processed and output to be saved
#
# Edit only `LECTURE_CODE` and `TOPIC` if needed. All inputs will live in `Data/LECTURE_TOPIC` and outputs in `Outputs/LECTURE_TOPIC`.

# %%
COURSE_DIR    = "/content/drive/MyDrive/Teaching/BIOINFO4-5203-F25"
LECTURE_CODE  = "L02-BLASTp"
TOPIC         = "diversity"

# point to the actual folder that contains the files
DATA_DIR   = f"{COURSE_DIR}/Data/{LECTURE_CODE}_{TOPIC}/Data"
OUTPUT_DIR = f"{COURSE_DIR}/Outputs/{LECTURE_CODE}_{TOPIC}"

print("📂 COURSE_DIR :", COURSE_DIR)
print("📁 DATA_DIR   :", DATA_DIR)
print("📁 OUTPUT_DIR :", OUTPUT_DIR)
# Out:
# 📂 COURSE_DIR : /content/drive/MyDrive/Teaching/BIOINFO4-5203-F25
# 📁 DATA_DIR   : /content/drive/MyDrive/Teaching/BIOINFO4-5203-F25/Data/L02-BLASTp_diversity/Data
# 📁 OUTPUT_DIR : /content/drive/MyDrive/Teaching/BIOINFO4-5203-F25/Outputs/L02-BLASTp_diversity

# %% [markdown]
# ##C.

# %% [markdown]
#  multi-FASTA of top hits per TaxID (one or more sequences per taxon). The cell below:
# 	•	uses your existing folders (Data/L0-species_diversity for input; writes to the same folder unless OUTPUT_DIR is already set),
# 	•	reads query_proteins.fasta and taxids.txt,
# 	•	for each TaxID, runs a separate BLAST restricted to that taxon (txid####[ORGN]), so we can attribute hits unambiguously,
# 	•	grabs the top N accessions from each BLAST,
# 	•	fetches their protein FASTA sequences,
# 	•	writes:
# 	•	per_taxid_top_hits.fasta (all sequences, grouped by taxid in headers),
# 	•	per_taxid_hits.tsv (who came from which taxid, evalue, %id, etc.),
# 	•	optional one FASTA per taxid (toggle with WRITE_SPLIT_FASTA).

# %%
# --- BLAST (per TaxID) -> collect top protein hits -> write multi-FASTA + TSV (adaptive search, matrix+gapcosts safe) ---
from Bio import Entrez, SeqIO
from Bio.Blast import NCBIWWW, NCBIXML
from pathlib import Path
import io, csv, re, time, sys

# ==== required ====
Entrez.email = "you@university.edu"   # <-- set your email

# ==== Alogorithm 'knobs' you can tweak ====
TOP_HITS_PER_TAXID = 1
EVALUE_STEPS       = [1e-5, 1e-2, 0.1]          # strict -> moderate -> permissive
HITLIST_SIZE       = max(200, TOP_HITS_PER_TAXID*10)
WRITE_SPLIT_FASTA  = False # if True, also writes one FASTA file per taxid (in addition to combined multi sequence file)
SLEEP_BETWEEN_CALLS = 0.3
FORCE_MODE = 'auto'                              # 'auto' | 'blastp' | 'blastx'

# Matrix + gap-costs mapping (what NCBI expects)
MATRIX_DEFAULT = "BLOSUM62"
GAPCOSTS_BY_MATRIX = {
    "BLOSUM62": "11 1",
    "BLOSUM45": "15 2",
    "PAM30":    "9 1",
    "PAM70":    "10 1",
}

# ==== paths ====
if 'DATA_DIR' in globals(): DATA_DIR = Path(DATA_DIR)
else: DATA_DIR = Path()

if 'OUTPUT_DIR' in globals(): OUTPUT_DIR = Path(OUTPUT_DIR)
else: OUTPUT_DIR = DATA_DIR
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

PROT_FASTA = DATA_DIR / "ndhA_Thermo.fas"
NUC_FASTA  = DATA_DIR / "query.fasta"
TAXIDS_TXT = DATA_DIR / "taxids-126.txt"

# ---- basic file checks ----
if not (PROT_FASTA.exists() or NUC_FASTA.exists()):
    raise FileNotFoundError(f"Neither {PROT_FASTA} nor {NUC_FASTA} found in {DATA_DIR}.")
if not TAXIDS_TXT.exists():
    raise FileNotFoundError(f"{TAXIDS_TXT} not found in {DATA_DIR}.")

# ==== helpers: accession parsing & normalization ====
def extract_accession(hit_id, hit_def, accession_attr):
    if accession_attr: return accession_attr.strip()
    for field in (hit_id, hit_def):
        m = re.search(r"([A-Z]{1,5}_?\d+(?:\.\d+)?)", field or "")
        if m: return m.group(1)
    return (hit_id or "unknown").strip()

def _norm_keys(acc_token: str):
    acc_token = acc_token.strip()
    base = acc_token.split(".", 1)[0]
    return {acc_token, base} if "." in acc_token else {acc_token, f"{base}.1"}

def fetch_protein_fasta(accessions):
    out = {}
    batch = list({a for a in accessions if a and a != "unknown"})
    while batch:
        chunk = batch[:50]; batch = batch[50:]
        try:
            h = Entrez.efetch(db="protein", id=",".join(chunk), rettype="fasta", retmode="text")
            txt = h.read(); h.close()
            parts = [t for t in txt.strip().split(">") if t]
            for rec_txt in parts:
                header, *seq_lines = rec_txt.splitlines()
                token = header.split()[0]
                fasta_txt = ">" + header + "\n" + "\n".join(seq_lines) + "\n"
                for k in _norm_keys(token):
                    out[k] = fasta_txt
        except Exception as e:
            sys.stderr.write(f"[warn] efetch failed for {chunk}: {e}\n")
        time.sleep(SLEEP_BETWEEN_CALLS)
    return out

# ==== robust query loader/detector ====
DNA_ALPHABET = set("ACGTNUWSMKRYBDHV-")
def detect_is_protein(seq_upper: str) -> bool:
    letters = [c for c in seq_upper if c.isalpha() or c == '*']
    return any((c not in DNA_ALPHABET) for c in letters)

def load_query():
    if PROT_FASTA.exists():
        rec = next(SeqIO.parse(str(PROT_FASTA), "fasta"))
        seq = str(rec.seq).upper()
        decided = 'blastp' if detect_is_protein(seq) else 'blastx'
        if FORCE_MODE in ('blastp','blastx'): decided = FORCE_MODE
        return decided, seq.replace("*",""), f"{PROT_FASTA.name}:{rec.id}"
    rec = next(SeqIO.parse(str(NUC_FASTA), "fasta"))
    seq = str(rec.seq).upper()
    decided = 'blastp' if detect_is_protein(seq) else 'blastx'
    if FORCE_MODE in ('blastp','blastx'): decided = FORCE_MODE
    if decided == 'blastp' and NUC_FASTA.name == "query.fasta":
        print("⚠️  Detected protein sequence in 'query.fasta'; using BLASTP.")
    return decided, seq.replace("*",""), f"{NUC_FASTA.name}:{rec.id}"

mode, query_seq, query_label = load_query()
print(f"📄 Query source: {query_label}")
print(f"🧪 Mode chosen: {mode.upper()} vs nr  | length={len(query_seq)}")

# ==== load TaxIDs ====
taxids = [t.strip() for t in TAXIDS_TXT.read_text().splitlines() if t.strip().isdigit()]
if not taxids: raise ValueError("taxids.txt is empty or contains no numeric TaxIDs.")
print(f"🧬 Loaded {len(taxids)} TaxIDs")

# ==== ADAPTIVE BLAST (matrix + gapcosts always paired) ====
def run_single_blast_adaptive(seq, taxid, program="blastp",
                              hitlist=HITLIST_SIZE, matrix=MATRIX_DEFAULT):
    q = f"txid{taxid}[ORGN]"
    last_xml, last_rec = None, None
    cur_matrix = matrix
    for e in EVALUE_STEPS:
        gapcosts = GAPCOSTS_BY_MATRIX.get(cur_matrix, GAPCOSTS_BY_MATRIX["BLOSUM62"])
        print(f"⏳ {program.upper()} vs nr | taxid={taxid} | E={e} | hits={hitlist} | matrix={cur_matrix} | gaps={gapcosts}\n   ENTREZ_QUERY: {q}")
        h = NCBIWWW.qblast(program=program, database="nr", sequence=seq,
                           expect=e, entrez_query=q,
                           hitlist_size=hitlist, descriptions=hitlist,
                           alignments=hitlist, matrix_name=cur_matrix,
                           gapcosts=gapcosts)
        xml = h.read(); h.close()
        try:
            rec = NCBIXML.read(io.StringIO(xml))
        except Exception:
            parser = NCBIXML.parse(io.StringIO(xml))
            rec = next(parser, None)
        last_xml, last_rec = xml, rec
        if rec and rec.alignments:
            return rec, xml, e, cur_matrix
        # One relaxation step: switch to BLOSUM45 (with its proper gapcosts) after the moderate E
        if e == 1e-2 and cur_matrix == "BLOSUM62":
            cur_matrix = "BLOSUM45"
    return last_rec, last_xml, e, cur_matrix

# ==== main loop -> XML + top hits -> fetch FASTA ====
all_rows = []
per_taxid_fastas = {}
xml_paths = []

for i, tid in enumerate(taxids, 1):
    try:
        record, xml, e_used, m_used = run_single_blast_adaptive(
            query_seq, tid, program=("blastp" if mode=="blastp" else "blastx"))
        print(f"   ↳ used E={e_used}, matrix={m_used}")
        xml_file = OUTPUT_DIR / f"{mode}_nr_taxid{tid}.xml"
        xml_file.write_text(xml); xml_paths.append(xml_file)

        if not record or not record.alignments:
            print(f"— No hits for taxid {tid}")
            continue

        hsps = []
        for aln in record.alignments:
            best = sorted(aln.hsps, key=lambda h: (h.expect, -h.identities))[0]
            acc = extract_accession(aln.hit_id, aln.hit_def, getattr(aln, "accession", None))
            pct_id = 100.0 * best.identities / best.align_length if best.align_length else 0.0
            hsps.append((aln, best, acc, pct_id))
        hsps.sort(key=lambda t: (t[1].expect, -t[3]))
        keep = hsps[:TOP_HITS_PER_TAXID]

        accs = [acc for _,_,acc,_ in keep]
        acc_to_fa = fetch_protein_fasta(accs)

        per_taxid_fastas.setdefault(tid, [])
        kept_now = 0
        for aln, best, acc, pct in keep:
            fa = None
            for k in _norm_keys(acc):
                fa = acc_to_fa.get(k)
                if fa: break
            if not fa:
                sys.stderr.write(f"[miss] No FASTA for {acc} (taxid {tid})\n")
                continue
            lines = fa.strip().splitlines()
            header = lines[0][1:]
            seq = "\n".join(lines[1:])
            new_header = f">taxid:{tid}|acc:{acc}|e:{best.expect:.2e}|pid:{pct:.2f}|len:{best.align_length} {header}"
            per_taxid_fastas[tid].append(new_header + "\n" + seq + "\n"); kept_now += 1

            all_rows.append([
                tid, acc, aln.title, aln.length, best.expect,
                best.identities, best.align_length, round(pct,2),
                min(best.query_start,best.query_end), max(best.query_start,best.query_end),
                min(best.sbjct_start,best.sbjct_end), max(best.sbjct_start,best.sbjct_end)
            ])
        print(f"✅ taxid {tid}: kept {kept_now} sequences")
    except Exception as e:
        print(f"⚠️ taxid {tid} failed: {e}")
    time.sleep(SLEEP_BETWEEN_CALLS)

# ==== write combined multi-FASTA + per-taxid FASTAs ====
multi_fa = OUTPUT_DIR / "per_taxid_top_hits.fasta"
with open(multi_fa, "w") as fh:
    for tid in taxids:
        for fa in per_taxid_fastas.get(tid, []):
            fh.write(fa)
print(f"💾 Multi-FASTA: {multi_fa}")

if WRITE_SPLIT_FASTA:
    for tid, fas in per_taxid_fastas.items():
        p = OUTPUT_DIR / f"taxid_{tid}_top_hits.fasta"
        with open(p, "w") as fh:
            for fa in fas: fh.write(fa)
    print("💾 Also wrote per-taxid FASTAs")

# ==== write table ====
tsv = OUTPUT_DIR / "per_taxid_hits.tsv"
with open(tsv, "w", newline="") as f:
    w = csv.writer(f, delimiter="\t")
    w.writerow(["taxid","accession","title","subject_length","evalue","identities","align_len","pct_identity","q_start","q_end","s_start","s_end"])
    w.writerows(all_rows)
print(f"📑 Table: {tsv}")
print(f"🗂 XML files saved: {len(xml_paths)}")
# Out:
# 📄 Query source: ndhA_Thermo.fas:sp|Q8DL32|NU1C_THEVB
# 🧪 Mode chosen: BLASTP vs nr  | length=372
# 🧬 Loaded 126 TaxIDs
# ⏳ BLASTP vs nr | taxid=543639 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid543639[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 543639: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=7217 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid7217[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 7217: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=334625 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid334625[ORGN]
# ⏳ BLASTP vs nr | taxid=334625 | E=0.01 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid334625[ORGN]
# ⏳ BLASTP vs nr | taxid=334625 | E=0.1 | hits=200 | matrix=BLOSUM45 | gaps=15 2
#    ENTREZ_QUERY: txid334625[ORGN]
#    ↳ used E=0.1, matrix=BLOSUM45
# — No hits for taxid 334625
# ⏳ BLASTP vs nr | taxid=34597 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid34597[ORGN]
# /usr/local/lib/python3.12/dist-packages/Bio/Blast/NCBIWWW.py:275: BiopythonWarning: BLAST request GFDENRBM016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 34597: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=274614 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid274614[ORGN]
# /usr/local/lib/python3.12/dist-packages/Bio/Blast/NCBIWWW.py:275: BiopythonWarning: BLAST request GFEF6U88016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 274614: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=7010 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid7010[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 7010: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=411798 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid411798[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 411798: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3107143 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3107143[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3107143: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3018267 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3018267[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3018267: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2026803 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2026803[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2026803: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=9764 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid9764[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 9764: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=9785 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid9785[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 9785: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=10090 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid10090[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 10090: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=51298 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid51298[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 51298: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=9940 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid9940[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 9940: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=9407 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid9407[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 9407: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=9823 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid9823[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 9823: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=45264 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid45264[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 45264: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=159855 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid159855[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 159855: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2886352 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2886352[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2886352: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2857077 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2857077[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2857077: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3075395 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3075395[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3075395: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2714958 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2714958[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2714958: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3081323 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3081323[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3081323: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3023278 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3023278[ORGN]
# ⏳ BLASTP vs nr | taxid=3023278 | E=0.01 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3023278[ORGN]
# ⏳ BLASTP vs nr | taxid=3023278 | E=0.1 | hits=200 | matrix=BLOSUM45 | gaps=15 2
#    ENTREZ_QUERY: txid3023278[ORGN]
#    ↳ used E=0.1, matrix=BLOSUM45
# — No hits for taxid 3023278
# ⏳ BLASTP vs nr | taxid=2847862 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2847862[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2847862: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1179 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1179[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1179: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1416614 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1416614[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1416614: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2812629 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2812629[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2812629: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2929567 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2929567[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2929567: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1982969 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1982969[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1982969: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2922243 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2922243[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2922243: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3050158 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3050158[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3050158: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2812896 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2812896[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2812896: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1552121 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1552121[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1552121: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1752064 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1752064[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1752064: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=287848 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid287848[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 287848: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2804519 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2804519[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2804519: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3064516 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3064516[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3064516: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2971801 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2971801[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2971801: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2664179 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2664179[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2664179: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2886104 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2886104[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2886104: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3088171 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3088171[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3088171: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2720476 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2720476[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2720476: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3350582 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3350582[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3350582: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2964529 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2964529[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2964529: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3083423 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3083423[ORGN]
# /usr/local/lib/python3.12/dist-packages/Bio/Blast/NCBIWWW.py:275: BiopythonWarning: BLAST request GFNBUG5A016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3083423: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2814275 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2814275[ORGN]
# /usr/local/lib/python3.12/dist-packages/Bio/Blast/NCBIWWW.py:275: BiopythonWarning: BLAST request GFNZ6T1B016 is taking longer than 10 minutes, consider re-issuing it
#   warnings.warn(
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2814275: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=457083 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid457083[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 457083: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3069706 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3069706[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3069706: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=52022 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid52022[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 52022: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1644118 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1644118[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1644118: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1408545 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1408545[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1408545: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=3396280 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid3396280[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 3396280: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=68909 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid68909[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 68909: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1737569 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1737569[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1737569: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=47478 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid47478[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 47478: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=186192 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid186192[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 186192: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=869210 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid869210[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 869210: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=277 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid277[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 277: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1955249 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1955249[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1955249: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=172827 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid172827[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 172827: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=208447 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid208447[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 208447: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=187137 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid187137[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 187137: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=270 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid270[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 270: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2908146 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2908146[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2908146: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2908145 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2908145[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2908145: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=271 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid271[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 271: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=482827 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid482827[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 482827: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=56956 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid56956[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 56956: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=540988 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid540988[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 540988: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=37636 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid37636[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 37636: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1761908 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1761908[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1761908: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2078690 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2078690[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2078690: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2908147 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2908147[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2908147: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=105358 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid105358[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 105358: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=7653 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid7653[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 7653: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2608793 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2608793[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2608793: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2032688 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2032688[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2032688: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1904752 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1904752[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1904752: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2026739 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2026739[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2026739: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1874737 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1874737[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1874737: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=39669 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid39669[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 39669: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=1945595 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid1945595[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 1945595: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=6645 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid6645[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 6645: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=94130 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid94130[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 94130: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2005738 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2005738[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2005738: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=115547 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid115547[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 115547: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2026795 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2026795[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2026795: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=2833567 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid2833567[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 2833567: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=6210 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid6210[ORGN]
# ⏳ BLASTP vs nr | taxid=6210 | E=0.01 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid6210[ORGN]
# ⏳ BLASTP vs nr | taxid=6210 | E=0.1 | hits=200 | matrix=BLOSUM45 | gaps=15 2
#    ENTREZ_QUERY: txid6210[ORGN]
#    ↳ used E=0.1, matrix=BLOSUM45
# ✅ taxid 6210: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=6211 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid6211[ORGN]
# ⏳ BLASTP vs nr | taxid=6211 | E=0.01 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid6211[ORGN]
# ⏳ BLASTP vs nr | taxid=6211 | E=0.1 | hits=200 | matrix=BLOSUM45 | gaps=15 2
#    ENTREZ_QUERY: txid6211[ORGN]
#    ↳ used E=0.1, matrix=BLOSUM45
# ✅ taxid 6211: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=6205 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid6205[ORGN]
# ⏳ BLASTP vs nr | taxid=6205 | E=0.01 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid6205[ORGN]
# ⏳ BLASTP vs nr | taxid=6205 | E=0.1 | hits=200 | matrix=BLOSUM45 | gaps=15 2
#    ENTREZ_QUERY: txid6205[ORGN]
#    ↳ used E=0.1, matrix=BLOSUM45
# ✅ taxid 6205: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=85433 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid85433[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 85433: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=53468 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid53468[ORGN]
# ⏳ BLASTP vs nr | taxid=53468 | E=0.01 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid53468[ORGN]
# ⏳ BLASTP vs nr | taxid=53468 | E=0.1 | hits=200 | matrix=BLOSUM45 | gaps=15 2
#    ENTREZ_QUERY: txid53468[ORGN]
#    ↳ used E=0.1, matrix=BLOSUM45
# ✅ taxid 53468: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=102285 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid102285[ORGN]
#    ↳ used E=1e-05, matrix=BLOSUM62
# ✅ taxid 102285: kept 1 sequences
# ⏳ BLASTP vs nr | taxid=60517 | E=1e-05 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid60517[ORGN]
# ⏳ BLASTP vs nr | taxid=60517 | E=0.01 | hits=200 | matrix=BLOSUM62 | gaps=11 1
#    ENTREZ_QUERY: txid60517[ORGN]
